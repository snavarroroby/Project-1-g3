# %%
#Tile

# %%
#Read csv files
import pandas as pd
csv_path = "Resources/global_power_plant_database.csv"
global_pwrplant = pd.read_csv(csv_path)
csv_path1 = "Resources/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_4701247.csv"
gdp_data = pd.read_csv(csv_path1,skiprows=4)
csv_path2 = "Resources/Human Development Index - Full.csv"
hdi_data = pd.read_csv(csv_path2)
# Out:
# C:\Users\mcael\AppData\Local\Temp\ipykernel_7712\403541752.py:4: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   global_pwrplant = pd.read_csv(csv_path)

# %%
#3 merged dataframes
full_data_merge = pd.merge(power_gdp_dframe,hdi_data,left_on="country_long",right_on="Country")

# %%
#Cleaned dataframe

# %%
#vis 
global_pwrplant
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# 34933     ZMB       Zambia                                     Victoria Falls
# 34934     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 34935     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
# ...

# %%
country_grouped_df=global_pwrplant.groupby(["country_long"]).sum()
country_grouped_df
# Out:
#                 capacity_mw   latitude   longitude  commissioning_year  \
# country_long
# Afghanistan         300.550   304.3886    613.8641                 0.0
# Albania            1529.000   331.4694    158.6606             13771.0
# Algeria           15873.800  1993.4829    190.8176             42029.0
# Angola             1071.180  -154.2466    201.6706                 0.0
# Antarctica            7.600  -155.6898    333.3876              1981.0
# ...                     ...        ...         ...                 ...
# Vietnam           41350.490  3834.7813  25181.1428            335500.0
# Western Sahara       23.400    23.6816    -15.9594                 0.0
# Yemen              1045.000    97.8290    311.0468             11915.0
# Zambia             2689.337  -218.5862    416.9842              5965.0
# Zimbabwe           1670.000   -34.9057     55.2319                 0.0
#
#                 year_of_capacity_data  generation_gwh_2013  \
# country_long
# ...

# %%
# 1-Top 5 energy producing countries all energy sources combined
country_grouped_df.sort_values(by=["capacity_mw"],ascending=False).head(5)
# Out:
#                           capacity_mw     latitude    longitude  \
# country_long
# China                     1415067.380  149201.2197  463471.0725
# United States of America  1204638.050  383563.5670 -925226.5060
# India                      316088.546   32847.3501  122385.7519
# Russia                     228220.050   29836.4145   33486.1996
# Japan                      215365.850   18715.0296   71293.1587
#
#                           commissioning_year  year_of_capacity_data  \
# country_long
# China                           2.178010e+06                    0.0
# United States of America        1.960284e+07             19763991.0
# India                           9.905180e+05               993348.0
# Russia                          5.408830e+05                    0.0
# Japan                           1.774220e+05                    0.0
#
#                           generation_gwh_2013  generation_gwh_2014  \
# country_long
# ...

# %%
# 2-Top 5 countries with the most installed power generation facilities (all energy sources combined)
installed_pwr=global_pwrplant.groupby(["country_long"]).count()
installed_pwr
# Out:
#                 country  name  gppd_idnr  capacity_mw  latitude  longitude  \
# country_long
# Afghanistan           9     9          9            9         9          9
# Albania               8     8          8            8         8          8
# Algeria              59    59         59           59        59         59
# Angola               14    14         14           14        14         14
# Antarctica            2     2          2            2         2          2
# ...                 ...   ...        ...          ...       ...        ...
# Vietnam             236   236        236          236       236        236
# Western Sahara        1     1          1            1         1          1
# Yemen                 7     7          7            7         7          7
# Zambia               15    15         15           15        15         15
# Zimbabwe              2     2          2            2         2          2
#
# ...

# %%
# !clean
installed_pwr.sort_values(by=["capacity_mw"],ascending=False).head(5)
# Out:
#                           country  name  gppd_idnr  capacity_mw  latitude  \
# country_long
# United States of America     9833  9833       9833         9833      9833
# China                        4235  4235       4235         4235      4235
# United Kingdom               2751  2751       2751         2751      2751
# Brazil                       2360  2360       2360         2360      2360
# France                       2155  2155       2155         2155      2155
#
#                           longitude  primary_fuel  other_fuel1  other_fuel2  \
# country_long
# United States of America       9833          9833         1429          269
# China                          4235          4235            1            0
# United Kingdom                 2751          2751            2            0
# Brazil                         2360          2360            0            0
# France                         2155          2155            0            0
#
# ...
